# %% [markdown]
# **After mounting changing directory to MyDrive**

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %ls
# Out:
# 'bandicam 2023-07-27 02-53-27-368.mp4'
# 'bandicam 2023-07-27 04-04-47-036.mp4'
#  CNN.pdf
#  CNN_ResearchPaper.pdf
# 'Colab Notebooks'/
# 'Convolutional neural network a review of models.pdf'
#  dataset/
# 'Getting started.pdf'
#  IMG_3316.JPG
#  IMG_3317.JPG
#  IMG_3318.JPG
#  IMG_3319.JPG
#  IMG_3320.JPG
#  IMG_3321.JPG
#  IMG_3340.JPG
#  IMG_3419.JPG
#  IMG_3420.JPG
#  IMG_3422.JPG
#  IMG_3509.JPG
#  IMG_3510.JPG
#  IMG_3511.JPG
#  IMG_3512.JPG
# 'Implementation of YOLO CNN.pdf'
#  instagram.gdoc
# 'Object_Detection_CNN (1).pdf'
#  Object_Detection_Yolo_CNN.pdf
# 'test_using_COCO_dataset (2).mp4'
#  YOLO.pdf
#  YOLO_ResearchPaper.pdf
#  yolov5/

# %% [markdown]
# **Cloning Official Repo of yolov5**

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15829, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 15829 (delta 20), reused 29 (delta 4), pack-reused 15768
# Receiving objects: 100% (15829/15829), 14.66 MiB | 11.61 MiB/s, done.
# Resolving deltas: 100% (10829/10829), done.

# %% [markdown]
# **Change directory to yolov5 folder**

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# %ls
# Out:
# benchmarks.py    data/       LICENSE          requirements.txt  tutorial.ipynb
# CITATION.cff     detect.py   models/          segment/          utils/
# classify/        export.py   README.md        setup.cfg         val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %% [markdown]
# **Installing all libraries mentioned in requirements.txt file**

# %%
# !pip install -qr requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.0/605.0 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00

# %% [markdown]
# **Training on custom dataset and pretrained weights**

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data ./dataset/data.yaml --weights yolov5s.pt --cache
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %% [markdown]
# **Exporting Model**

# %%
# !python export.py --weights ./runs/train/exp2/weights/best.pt --img-size 640 --batch-size 1
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# export: data=data/coco128.yaml, weights=['./runs/train/exp2/weights/best.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript']
# YOLOv5 🚀 v7.0-196-gacdf73b Python-3.10.6 torch-2.0.1+cu118 CPU
#
# ...

# %% [markdown]
# **Testing/Detecting Car**

# %%
# !python detect.py --source cctv2.mp4 --weights ./runs/train/exp2/weights/best.pt --img-size 640 --conf 0.4 --device 0
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# !python detect.py --source cctv1.mp4 --weights ./runs/train/exp2/weights/best.pt --img-size 640 --conf 0.4 --device 0
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...
